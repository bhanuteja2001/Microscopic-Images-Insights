# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, sys, random
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install -qr '/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/requirements.txt'  # install dependencies
# Out:
#      |████████████████████████████████| 645kB 6.4MB/s

# %% [markdown]
# #**NECCESSARY FILES FOR DETECTION AND LATER ADD THIS PATH TO THE SYSTEM VARIABLE**

# %% [markdown]
# <img src="https://github.com/bala-codes/Yolo-v5_Object_Detection_Blood_Cell_Count/blob/master/imgs/Dependency_files.PNG?raw=true" width="200%">

# %%
## Add the path where you have stored the neccessary supporting files to run detect.py ##
sys.path.insert(0, '/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files')
print(sys.path)
cwd = os.getcwd()
print(cwd)
# Out:
# ['/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files', '', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']
# /content

# %% [markdown]
# ## Single Image predictions

# %%
## Beware the contents in the output folder will be deleted for every prediction
output = !python '/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/detect.py' --source '/content/drive/MyDrive/Blood Cells/neutrophilsinchemopatient.jpg' --weights '/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/best_BCCM.pt' --output '/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES'

print(output)
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES', save_txt=False, source='/content/drive/MyDrive/Blood Cells/neutrophilsinchemopatient.jpg', update=False, view_img=False, weights=['/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/best_BCCM.pt'])", "Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)", '', 'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients', 'image 1/1 /content/drive/MyDrive/Blood Cells/neutrophilsinchemopatient.jpg: 512x640 78 RBCs, 2 WBCs, Done. (0.022s)', 'Results saved to /content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES', 'Done. (0.273s)']

# %%
output
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES', save_txt=False, source='/content/drive/MyDrive/Blood Cells/neutrophilsinchemopatient.jpg', update=False, view_img=False, weights=['/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/best_BCCM.pt'])",
#  "Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)",
#  '',
#  'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients',
#  'image 1/1 /content/drive/MyDrive/Blood Cells/neutrophilsinchemopatient.jpg: 512x640 78 RBCs, 2 WBCs, Done. (0.022s)',
#  'Results saved to /content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES',
#  'Done. (0.273s)']

# %%
print("Number of WBCs : ",output[-3].split(' ')[-4])
print("Number of RBCs : ",output[-3].split(' ')[-6])
# Out:
# Number of WBCs :  2
# Number of RBCs :  78

# %%
img = plt.imread('/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES/neutrophilsinchemopatient.jpg')
plt.imshow(img)

# %% [markdown]
# ## Predict image in folders

# %%
## Beware the contents in the output folder will be deleted for every prediction
output = !python '/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/detect.py' --source '/content/drive/MyDrive/Blood Cells/INPUT/' --weights '/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/best_BCCM.pt' --output '/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES'

print(output)
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES', save_txt=False, source='/content/drive/MyDrive/Blood Cells/INPUT/', update=False, view_img=False, weights=['/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/best_BCCM.pt'])", "Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)", '', 'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients', 'image 1/2 /content/drive/MyDrive/Blood Cells/INPUT/2tt400_b.jpg: 512x640 Done. (0.020s)', 'image 2/2 /content/drive/MyDrive/Blood Cells/INPUT/neutrophilsinchemopatient.jpg: 512x640 78 RBCs, 2 WBCs, Done. (0.020s)', 'Results saved to /content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES', 'Done. (0.144s)']

# %%
output
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES', save_txt=False, source='/content/drive/MyDrive/Blood Cells/INPUT/', update=False, view_img=False, weights=['/content/drive/MyDrive/Blood Cells/YoloV5/Yolo-V5_Object_Detection_Blood_Cell_Count_and_Detection/Inference_files/best_BCCM.pt'])",
#  "Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)",
#  '',
#  'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients',
#  'image 1/2 /content/drive/MyDrive/Blood Cells/INPUT/2tt400_b.jpg: 512x640 Done. (0.020s)',
#  'image 2/2 /content/drive/MyDrive/Blood Cells/INPUT/neutrophilsinchemopatient.jpg: 512x640 78 RBCs, 2 WBCs, Done. (0.020s)',
#  'Results saved to /content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES',
#  'Done. (0.144s)']

# %%
disp_images = glob('/content/drive/MyDrive/Blood Cells/Checkpoints/OUTPUT IMAGES/*')

img = plt.imread(disp_images[1])
plt.imshow(img)

# %%
img = plt.imread(disp_images[1])
plt.imshow(img)
